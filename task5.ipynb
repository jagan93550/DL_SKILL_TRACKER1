# %%
# TASK 5: Optimization Techniques

import torch
import torch.nn as nn
import torch.optim as optim

# Dataset
X = torch.randn(100, 10)
y = torch.randint(0, 2, (100, 1)).float()

model = nn.Sequential(
    nn.Linear(10, 5),
    nn.ReLU(),
    nn.Linear(5, 1),
    nn.Sigmoid()
)

criterion = nn.BCELoss()

# Different optimizers
optimizers = {
    'SGD': optim.SGD(model.parameters(), lr=0.01),
    'Adam': optim.Adam(model.parameters(), lr=0.001),
    'RMSprop': optim.RMSprop(model.parameters(), lr=0.001)
}

# Compare optimizers
for opt_name, optimizer in optimizers.items():
    model_copy = nn.Sequential(
        nn.Linear(10, 5),
        nn.ReLU(),
        nn.Linear(5, 1),
        nn.Sigmoid()
    )
    optimizer = optim.SGD(model_copy.parameters(), lr=0.01) if opt_name == 'SGD' else (
        optim.Adam(model_copy.parameters(), lr=0.001) if opt_name == 'Adam' else 
        optim.RMSprop(model_copy.parameters(), lr=0.001)
    )
    
    for epoch in range(20):
        outputs = model_copy(X)
        loss = criterion(outputs, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    print(f'{opt_name} - Final Loss: {loss.item():.4f}')
# Out:
# Batch Normalization:
# tensor([[-1.2247, -1.2247, -1.2247],
#         [ 0.0000,  0.0000,  0.0000],
#         [ 1.2247,  1.2247,  1.2247]])
#
# Layer Normalization:
# tensor([[-1.2247,  0.0000,  1.2247],
#         [-1.2247,  0.0000,  1.2247],
#         [-1.2247,  0.0000,  1.2247]])
