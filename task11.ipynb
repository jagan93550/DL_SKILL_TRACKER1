# %%
# TASK 11: Regularization Techniques

import torch
import torch.nn as nn
import torch.optim as optim

class RegularizedModel(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(RegularizedModel, self).__init__()
        self.fc1 = nn.Linear(10, 50)
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(50, 50)
        self.fc3 = nn.Linear(50, 1)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.dropout(x)
        x = torch.relu(x)
        x = self.fc2(x)
        x = self.dropout(x)
        x = torch.relu(x)
        x = self.fc3(x)
        return x

# Create model with regularization
model = RegularizedModel(dropout_rate=0.5)

# Data
X = torch.randn(100, 10)
y = torch.randn(100, 1)

# Optimizer with L2 regularization (weight decay)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
criterion = nn.MSELoss()

# Training loop with regularization
epochs = 50
for epoch in range(epochs):
    model.train()
    output = model(X)
    loss = criterion(output, y)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if (epoch + 1) % 10 == 0:
        print(f'Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}')

print("Regularization techniques applied successfully!")
# Out:
# Patch sequence: torch.Size([1, 16, 64])
# Attention output: torch.Size([1, 16, 64])
