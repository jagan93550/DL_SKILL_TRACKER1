# %%
# TASK 2: Weight Initialization

import torch
import torch.nn as nn

model = nn.Linear(10, 5)

# Xavier initialization
nn.init.xavier_uniform_(model.weight)

print("Xavier weights:")
print(model.weight)

# He initialization
model2 = nn.Linear(10, 5)
nn.init.kaiming_uniform_(model2.weight)

print("\nHe weights:")
print(model2.weight)
# Out:
# Xavier weights:
# Parameter containing:
# tensor([[-0.4907, -0.0572,  0.0326, -0.5961, -0.1449,  0.5952,  0.2963,  0.0867,
#           0.6259,  0.1455],
#         [-0.2097, -0.5072, -0.2424, -0.1039, -0.5545,  0.5343,  0.4349, -0.5024,
#          -0.1099,  0.0178],
#         [ 0.3759, -0.0147,  0.2337, -0.4430,  0.1520, -0.3480, -0.3535, -0.5235,
#          -0.2437, -0.2467],
#         [-0.1442,  0.2210, -0.4652, -0.0783,  0.6116, -0.2053,  0.0941, -0.2809,
#          -0.2132,  0.5619],
#         [-0.6015,  0.1887, -0.4253, -0.4504,  0.0218,  0.1044,  0.5866, -0.6258,
#          -0.3905,  0.2065]], requires_grad=True)
#
# Kaiming weights:
# Parameter containing:
# tensor([[-0.0057, -0.5450,  0.6739,  0.0441,  0.4044,  0.6746, -0.6021, -0.6959,
#          -0.2833,  0.6984],
#         [-0.5575, -0.0833,  0.2373,  0.5045, -0.0843, -0.0966,  0.3970, -0.1456,
#          -0.0296, -0.5200],
#         [-0.0464, -0.4475, -0.1603,  0.6602, -0.7701, -0.2371,  0.2851,  0.0554,
#          -0.1552, -0.5466],
#         [-0.7184,  0.3073,  0.0668,  0.3382,  0.5692, -0.5865,  0.5187,  0.3157,
#          -0.3432, -0.5695],
#         [ 0.4918, -0.5621,  0.3590, -0.3853, -0.0809, -0.3639, -0.3145, -0.5234,
#           0.1547,  0.1602]], requires_grad=True)
