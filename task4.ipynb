# %%
# TASK 4: Training Loop with PyTorch

import torch
import torch.nn as nn
import torch.optim as optim

# Create simple dataset
X = torch.randn(100, 10)
y = torch.randint(0, 2, (100, 1)).float()

# Define model
model = nn.Sequential(
    nn.Linear(10, 5),
    nn.ReLU(),
    nn.Linear(5, 1),
    nn.Sigmoid()
)

# Loss and optimizer
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Training loop
epochs = 50
for epoch in range(epochs):
    # Forward pass
    outputs = model(X)
    loss = criterion(outputs, y)
    
    # Backward pass
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}')

print("Training completed!")
# Out:
# Step 1 Weight: 4.0
# Step 2 Weight: 3.2
# Step 3 Weight: 2.56
# Step 4 Weight: 2.048
# Step 5 Weight: 1.638
#
# Basic optimizer update completed.
